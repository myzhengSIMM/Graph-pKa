#
#
# layer:
# (200, 200)
# alpha:
# 0.001
# 0.8332176210035571
# 1.3927879717110443
# 0.8467097173495788
#
#
# layer:
# (400, 400)
# alpha:
# 0.0001
# 0.8616910879904145
# 1.3773654376555615
# 0.8500857308028278
#
#
# layer:
# (400, 400)
# alpha:
# 0.001
# 0.871226496961134
# 1.4082634308484716
# 0.84328433361174
#
#
# layer:
# (800, 800)
# alpha:
# 0.0001
# 0.9559684506625253
# 1.5518526310143177
# 0.809697031103713
#
#
# layer:
# (800, 800)
# alpha:
# 0.001
# 1.0091120482263018
# 1.555103482378457
# 0.8088988952108436
#
#
# layer:
# (50, 50, 50)
# alpha:
# 0.0001
# 0.7975531415209574
# 1.3327066503359302
# 0.8596495725048557
#
#
# layer:
# (50, 50, 50)
# alpha:
# 0.001
# 0.8066179910828863
# 1.342651731828673
# 0.8575470777399017
#
#
# layer:
# (100, 100, 100)
# alpha:
# 0.0001
# 0.8041411083776017
# 1.3713885543349744
# 0.8513839716242374
#
#
# layer:
# (100, 100, 100)
# alpha:
# 0.001
# 0.8251928976859267
# 1.360947746688939
# 0.8536382775714766
#
#
# layer:
# (200, 200, 200)
# alpha:
# 0.0001
# 0.8835537919546798
# 1.3815792389347705
# 0.8491670563220638
#
#
# layer:
# (200, 200, 200)
# alpha:
# 0.001
# 0.8416292714952734
# 1.3357915162960103
# 0.8589990717316777
#
#
# layer:
# (400, 400, 400)
# alpha:
# 0.0001
# 0.8794395635184321
# 1.3877178597809023
# 0.8478237193414648
#
#
# layer:
# (400, 400, 400)
# alpha:
# 0.001
# 0.9145437409491987
# 1.428119837889045
# 0.8388338194037586
#
#
# layer:
# (800, 800, 800)
# alpha:
# 0.0001
# 1.084198773879199
# 1.674499313587087
# 0.7784281633292733
#
#
# layer:
# (800, 800, 800)
# alpha:
# 0.001
# 1.0573359419896091
# 1.617699847727123
# 0.7932047784490762
#
#
# layer:
# (50, 50, 50, 50)
# alpha:
# 0.0001
# 0.8844213713464767
# 1.458213699766923
# 0.8319699494111189
#
#
# layer:
# (50, 50, 50, 50)
# alpha:
# 0.001
# 0.8067367462027374
# 1.3326481930378433
# 0.8596618847820325
#
#
# layer:
# (100, 100, 100, 100)
# alpha:
# 0.0001
# 0.8251279747144654
# 1.3930423792800146
# 0.8466537120269206
#
#
# layer:
# (100, 100, 100, 100)
# alpha:
# 0.001
# 0.815783686812355
# 1.34351175731733
# 0.8573645249920676
#
#
# layer:
# (200, 200, 200, 200)
# alpha:
# 0.0001
# 0.8121274507965855
# 1.366548831923369
# 0.8524310726255762
#
#
# layer:
# (200, 200, 200, 200)
# alpha:
# 0.001
# 0.8329757992252669
# 1.3361518747843188
# 0.8589229854047248
#
#
# layer:
# (400, 400, 400, 400)
# alpha:
# 0.0001
# 0.9246157725147606
# 1.4413014337281973
# 0.8358449501665467
#
#
# layer:
# (400, 400, 400, 400)
# alpha:
# 0.001
# 0.8398453673340667
# 1.3787756332936227
# 0.8497785985538833
#
#
# layer:
# (800, 800, 800, 800)
# alpha:
# 0.0001
# 0.969683498169833
# 1.5520191272733745
# 0.8096561941949985
#
#
# layer:
# (800, 800, 800, 800)
# alpha:
# 0.001
# 0.9287430644980763
# 1.4565476260333707
# 0.8323536936125104

# %%
for layer in layers:
    for alpha in alpha_list:
        model = MLPRegressor(layer,alpha = alpha,learning_rate_init =0.0001, random_state= 0)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)
        print('layer:')
        print(layer)
        print('alpha:')
        print(alpha)
        print(mean_absolute_error(y_val, y_pred))
        print(mean_squared_error(y_val, y_pred)**0.5)
        print(r2_score(y_val, y_pred))
        print('\n')
# Out:
# /home/graphnn/xjc/anaconda/envs/rdkit-env/lib/python3.6/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# layer:
# (50, 50)
# alpha:
# 0.0001
# 0.8466820025010642
# 1.4376352676434356
# 0.8366789939731101
# /home/graphnn/xjc/anaconda/envs/rdkit-env/lib/python3.6/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# layer:
# (50, 50)
# alpha:
# 0.001
# 0.8549101386729199
# 1.436729909599052
# 0.836884633652249
#
#
# layer:
# (100, 100)
# alpha:
# 0.0001
# 0.844107004218353
# 1.4025842556189017
# 0.844545775335546
#
#
# layer:
# (100, 100)
# alpha:
# 0.001
# 0.8459176345911325
# 1.4167376015761723
# 0.84139259804002
#
#
# layer:
# (200, 200)
# alpha:
# 0.0001
# 0.7798612368140592
# 1.34679951101913
# 0.8566655744981798
#
#
# layer:
# (200, 200)
# alpha:
# 0.001
# 0.7684072508293063
# 1.3415960891863932
# 0.8577709932330501
#
#
# layer:
# (400, 400)
# alpha:
# 0.0001
# 0.7581846109585832
# 1.2904029140782973
# 0.86841836447101
#
#
# layer:
# (400, 400)
# alpha:
# 0.001
# 0.7485047742475208
# 1.2818408037566296
# 0.8701587182659408
#
#
# layer:
# (800, 800)
# alpha:
# 0.0001
# 0.7512029591731607
# 1.295301987644105
# 0.8674173565139658
#
#
# layer:
# (800, 800)
# alpha:
# 0.001
# 0.7614232674379909
# 1.2982783674784768
# 0.8668073525299946
#
#
# layer:
# (50, 50, 50)
# alpha:
# 0.0001
# 0.8164399259698899
# 1.398031091254504
# 0.8455534292642839
#
#
# layer:
# (50, 50, 50)
# alpha:
# 0.001
# 0.8293023268786954
# 1.4225526974746052
# 0.8400878961551613
#
#
# layer:
# (100, 100, 100)
# alpha:
# 0.0001
# 0.8073458945368409
# 1.3777070621970107
# 0.8500113558499496
#
#
# layer:
# (100, 100, 100)
# alpha:
# 0.001
# 0.802426454820453
# 1.3676188378277292
# 0.8521998896081859
#
#
# layer:
# (200, 200, 200)
# alpha:
# 0.0001
# 0.7642424706414115
# 1.3175863114274882
# 0.8628162221695898
#
#
# layer:
# (200, 200, 200)
# alpha:
# 0.001
# 0.7764570909868266
# 1.332555448886194
# 0.8596814174488039
#
#
# layer:
# (400, 400, 400)
# alpha:
# 0.0001
# 0.7612689687923793
# 1.2932540822503746
# 0.8678362581691546
#
#
# layer:
# (400, 400, 400)
# alpha:
# 0.001
# 0.7570115094876303
# 1.2891065591120903
# 0.8686826087983741
#
#
# layer:
# (800, 800, 800)
# alpha:
# 0.0001
# 0.7261366154431886
# 1.2693892951514336
# 0.8726689638574496
#
#
# layer:
# (800, 800, 800)
# alpha:
# 0.001
# 0.7289495107044757
# 1.2680004572045906
# 0.8729474370319602
#
#
# layer:
# (50, 50, 50, 50)
# alpha:
# 0.0001
# 0.8320713870972684
# 1.3804392264347998
# 0.8494158737526414
#
#
# layer:
# (50, 50, 50, 50)
# alpha:
# 0.001
# 0.8139417705518521
# 1.3643926497597532
# 0.8528963826976753
#
#
# layer:
# (100, 100, 100, 100)
# alpha:
# 0.0001
# 0.8082989064766232
# 1.3726704921440882
# 0.8511059970850563
#
#
# layer:
# (100, 100, 100, 100)
# alpha:
# 0.001
# 0.8010625628876231
# 1.361834894725501
# 0.8534474005370726
#
#
# layer:
# (200, 200, 200, 200)
# alpha:
# 0.0001
# 0.7819733282225614
# 1.340945773085709
# 0.857908846043477
#
#
# layer:
# (200, 200, 200, 200)
# alpha:
# 0.001
# 0.7886404955701589
# 1.345186083530347
# 0.8570087899196756
#
#
# layer:
# (400, 400, 400, 400)
# alpha:
# 0.0001
# 0.7398490719872255
# 1.272286102118104
# 0.8720871497448652
#
#
# layer:
# (400, 400, 400, 400)
# alpha:
# 0.001
# 0.7419716469822637
# 1.2707250161791297
# 0.872400853473671
#
#
# layer:
# (800, 800, 800, 800)
# alpha:
# 0.0001
# 0.7362235751670319
# 1.2808381587103084
# 0.8703617603330431
#
#
# layer:
# (800, 800, 800, 800)
# alpha:
# 0.001
# 0.7262591535761703
# 1.263090468720345
# 0.8739294852917676

# %% [markdown]
# # 加到5层,碱

# %%
df_train = pd.read_csv('./Dataset/basic_train_0.70_FP.csv',header = None)
df_val = pd.read_csv('./Dataset/basic_val_0.15_FP.csv',header = None)

# %%
layers = [(50,50,50,50,50),(100,100,100,100,100),(200,200,200,200,200),(400,400,400,400,400),(800,800,800,800,800)]
alpha_list = [0.0001,0.001]
learning_rate_init_list = [0.0001, 0.001, 0.01]

# %%
train_data_label = np.array(df_train)
print(train_data_label.shape)
val_data_label = np.array(df_val)
print(val_data_label.shape)
X_train, X_val, y_train, y_val = train_data_label[:,1:],val_data_label[:,1:],train_data_label[:,0],val_data_label[:,0]
# Out:
# (5905, 9122)
# (1265, 9122)

# %%
for layer in layers:
    for alpha in alpha_list:
        for learning_rate_init in learning_rate_init_list :
            model = MLPRegressor(layer,alpha = alpha,learning_rate_init =learning_rate_init, random_state= 0)
            model.fit(X_train, y_train)
            y_pred = model.predict(X_val)
            print('layer:')
            print(layer)
            print('alpha:')
            print(alpha)
            print('learning_rate_init:')
            print(learning_rate_init)
            print(mean_absolute_error(y_val, y_pred))
            print(mean_squared_error(y_val, y_pred)**0.5)
            print(r2_score(y_val, y_pred))
            print('\n')
# Out:
# layer:
# (50, 50, 50, 50, 50)
# alpha:
# 0.0001
# learning_rate_init:
# 0.0001
# 0.7551157006375374
# 1.1776540273059688
# 0.8598110439265252
#
#
# layer:
# (50, 50, 50, 50, 50)
# alpha:
# 0.0001
# learning_rate_init:
# 0.001
# 0.7160337685441364
# 1.1355231124991205
# 0.8696622213169362
#
#
# layer:
# (50, 50, 50, 50, 50)
# alpha:
# 0.0001
# learning_rate_init:
# 0.01
# 0.8231744798745448
# 1.2503712854705493
# 0.8419638861150277
#
#
# layer:
# (50, 50, 50, 50, 50)
# alpha:
# 0.001
# learning_rate_init:
# 0.0001
# 0.7679995769455544
# 1.1763218025509792
# 0.8601280429009391
#
#
# layer:
# (50, 50, 50, 50, 50)
# alpha:
# 0.001
# learning_rate_init:
# 0.001
# 0.7083761247141583
# 1.1103888373865753
# 0.875368295964968
#
#
# layer:
# (50, 50, 50, 50, 50)
# alpha:
# 0.001
# learning_rate_init:
# 0.01
# 0.7243753261456595
# 1.13237620462348
# 0.8703836379614001
#
#
# layer:
# (100, 100, 100, 100, 100)
# alpha:
# 0.0001
# learning_rate_init:
# 0.0001
# 0.7452071253967278
# 1.1490591127559795
# 0.8665363182541608
#
#
# layer:
# (100, 100, 100, 100, 100)
# alpha:
# 0.0001
# learning_rate_init:
# 0.001
# 0.6797644905383341
# 1.073020274135763
# 0.8836157494956737
#
#
# layer:
# (100, 100, 100, 100, 100)
# alpha:
# 0.0001
# learning_rate_init:
# 0.01
# 0.7248469693687258
# 1.1376612613582497
# 0.8691709165722383
#
#
# layer:
# (100, 100, 100, 100, 100)
# alpha:
# 0.001
# learning_rate_init:
# 0.0001
# 0.7461748669419952
# 1.1663761293084194
# 0.8624832485775614
#
#
# layer:
# (100, 100, 100, 100, 100)
# alpha:
# 0.001
# learning_rate_init:
# 0.001
# 0.6650388536207166
# 1.069404703751578
# 0.8843987477645778
#
#
# layer:
# (100, 100, 100, 100, 100)
# alpha:
# 0.001
# learning_rate_init:
# 0.01
# 0.7964055025356356
# 1.2235963127389284
# 0.8486596696189415
#
#
# layer:
# (200, 200, 200, 200, 200)
# alpha:
# 0.0001
# learning_rate_init:
# 0.0001
# 0.6925152942470687
# 1.0916658172581124
# 0.8795358607206601
#
#
# layer:
# (200, 200, 200, 200, 200)
# alpha:
# 0.0001
# learning_rate_init:
# 0.001
# 0.7308794189358968
# 1.1032068575419325
# 0.8769753143378725
#
#
# layer:
# (200, 200, 200, 200, 200)
# alpha:
# 0.0001
# learning_rate_init:
# 0.01
# 0.823453996238343
# 1.2363682580772397
# 0.845483788319623
#
#
# layer:
# (200, 200, 200, 200, 200)
# alpha:
# 0.001
# learning_rate_init:
# 0.0001
# 0.6824611902918598
# 1.0794364188957548
# 0.8822197446212595
#
#
# layer:
# (200, 200, 200, 200, 200)
# alpha:
# 0.001
# learning_rate_init:
# 0.001
# 0.6395090833818644
# 1.0265773691719533
# 0.8934725010909407
#
#
# layer:
# (200, 200, 200, 200, 200)
# alpha:
# 0.001
# learning_rate_init:
# 0.01
# 0.8064788880255926
# 1.1813629725302939
# 0.8589266212922255
#
#
# layer:
# (400, 400, 400, 400, 400)
# alpha:
# 0.0001
# learning_rate_init:
# 0.0001
# 0.6793903005509618
# 1.0490856543349627
# 0.8887499396593388
#
#
# layer:
# (400, 400, 400, 400, 400)
# alpha:
# 0.0001
# learning_rate_init:
# 0.001
# 0.7111013994671447
# 1.0742010822911405
# 0.8833594578082004
#
#
# layer:
# (400, 400, 400, 400, 400)
# alpha:
# 0.0001
# learning_rate_init:
# 0.01
# 2.6256188948630754
# 3.1649819494954627
# -0.01256015490344109
#
#
# layer:
# (400, 400, 400, 400, 400)
# alpha:
# 0.001
# learning_rate_init:
# 0.0001
# 0.6531798951740733
# 1.031896919869018
# 0.892365625634414
#
#
# layer:
# (400, 400, 400, 400, 400)
# alpha:
# 0.001
# learning_rate_init:
# 0.001
# 0.6932264824973935
# 1.0772308749865045
# 0.8827005587480542
#
#
# layer:
# (400, 400, 400, 400, 400)
# alpha:
# 0.001
# learning_rate_init:
# 0.01
# 2.6031209697109734
# 3.1549623822389172
# -0.006159261773062141
#
#
# layer:
# (800, 800, 800, 800, 800)
# alpha:
# 0.0001
# learning_rate_init:
# 0.0001
# 0.6488623873461967
# 1.036094217969061
# 0.8914882272173136
#
#
# layer:
# (800, 800, 800, 800, 800)
# alpha:
# 0.0001
# learning_rate_init:
# 0.001
# 0.7519231291237692
# 1.098603615010542
# 0.8779998383670347
#
#
# layer:
# (800, 800, 800, 800, 800)
# alpha:
# 0.0001
# learning_rate_init:
# 0.01
# 0.859926521052485
# 1.2442501122157386
# 0.8435074253519353
#
#
# layer:
# (800, 800, 800, 800, 800)
# alpha:
# 0.001
# learning_rate_init:
# 0.0001
# 0.6406912262781693
# 1.0269200144616863
# 0.8934013769099498
#
#
# layer:
# (800, 800, 800, 800, 800)
# alpha:
# 0.001
# learning_rate_init:
# 0.001
# 0.656563622563623
# 1.041978622322865
# 0.8902521612959278
#
#
# layer:
# (800, 800, 800, 800, 800)
# alpha:
# 0.001
# learning_rate_init:
# 0.01
# 0.9861105843383939
# 1.4606549236571318
# 0.7843380079075191
# /home/graphnn/xjc/anaconda/envs/rdkit-env/lib/python3.6/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# # 加到5层,酸

# %%
df_train = pd.read_csv('./Dataset/acidic_train_0.70_FP.csv',header = None)
df_val = pd.read_csv('./Dataset/acidic_val_0.15_FP.csv',header = None)

# %%
layers = [(50,50,50,50,50),(100,100,100,100,100),(200,200,200,200,200),(400,400,400,400,400),(800,800,800,800,800)]
alpha_list = [0.0001,0.001]
learning_rate_init_list = [0.0001, 0.001, 0.01]

# %%
train_data_label = np.array(df_train)
print(train_data_label.shape)
val_data_label = np.array(df_val)
print(val_data_label.shape)
X_train, X_val, y_train, y_val = train_data_label[:,1:],val_data_label[:,1:],train_data_label[:,0],val_data_label[:,0]
# Out:
# (6337, 9122)
# (1358, 9122)

# %%
for layer in layers:
    for alpha in alpha_list:
        for learning_rate_init in learning_rate_init_list :
            model = MLPRegressor(layer,alpha = alpha,learning_rate_init =learning_rate_init, random_state= 0)
            model.fit(X_train, y_train)
            y_pred = model.predict(X_val)
            print('layer:')
            print(layer)
            print('alpha:')
            print(alpha)
            print('learning_rate_init:')
            print(learning_rate_init)
            print(mean_absolute_error(y_val, y_pred))
            print(mean_squared_error(y_val, y_pred)**0.5)
            print(r2_score(y_val, y_pred))
            print('\n')
# Out:
# layer:
# (50, 50, 50, 50, 50)
# alpha:
# 0.0001
# learning_rate_init:
# 0.0001
# 0.8102799258363632
# 1.367637134117166
# 0.8521959349804602
#
#
# layer:
# (50, 50, 50, 50, 50)
# alpha:
# 0.0001
# learning_rate_init:
# 0.001
# 0.7819118573164919
# 1.3199029101555466
# 0.8623334012075394
#
#
# layer:
# (50, 50, 50, 50, 50)
# alpha:
# 0.0001
# learning_rate_init:
# 0.01
# 0.7778358149025811
# 1.334046564328058
# 0.8593672117335378
#
#
# layer:
# (50, 50, 50, 50, 50)
# alpha:
# 0.001
# learning_rate_init:
# 0.0001
# 0.8109303042188576
# 1.3759596514628514
# 0.85039158988128
#
#
# layer:
# (50, 50, 50, 50, 50)
# alpha:
# 0.001
# learning_rate_init:
# 0.001
# 0.7796435194144503
# 1.3057936587695214
# 0.8652608756890859
#
#
# layer:
# (50, 50, 50, 50, 50)
# alpha:
# 0.001
# learning_rate_init:
# 0.01
# 0.7845111124557955
# 1.3279003640450806
# 0.8606600693875842
#
#
# layer:
# (100, 100, 100, 100, 100)
# alpha:
# 0.0001
# learning_rate_init:
# 0.0001
# 0.7875966974731625
# 1.3024711670939249
# 0.865945670082773
#
#
# layer:
# (100, 100, 100, 100, 100)
# alpha:
# 0.0001
# learning_rate_init:
# 0.001
# 0.7253309010561771
# 1.2676504234613877
# 0.8730175735142706
#
#
# layer:
# (100, 100, 100, 100, 100)
# alpha:
# 0.0001
# learning_rate_init:
# 0.01
# 0.7869480186954466
# 1.328425445196968
# 0.8605498514243467
#
#
# layer:
# (100, 100, 100, 100, 100)
# alpha:
# 0.001
# learning_rate_init:
# 0.0001
# 0.7930225285705821
# 1.3193066520034658
# 0.86245775321935
#
#
# layer:
# (100, 100, 100, 100, 100)
# alpha:
# 0.001
# learning_rate_init:
# 0.001
# 0.7378971795058172
# 1.2648205406662338
# 0.8735838878212343
#
#
# layer:
# (100, 100, 100, 100, 100)
# alpha:
# 0.001
# learning_rate_init:
# 0.01
# 0.7806919041804493
# 1.3164109546395453
# 0.8630608633984969
#
#
# layer:
# (200, 200, 200, 200, 200)
# alpha:
# 0.0001
# learning_rate_init:
# 0.0001
# 0.7856619679044009
# 1.3243829586265152
# 0.8613972721480558
#
#
# layer:
# (200, 200, 200, 200, 200)
# alpha:
# 0.0001
# learning_rate_init:
# 0.001
# 0.7076762928654758
# 1.2349687216168317
# 0.8794807205504408
#
#
# layer:
# (200, 200, 200, 200, 200)
# alpha:
# 0.0001
# learning_rate_init:
# 0.01
# 0.8162203498214458
# 1.3912255481161728
# 0.8470534452132001
#
#
# layer:
# (200, 200, 200, 200, 200)
# alpha:
# 0.001
# learning_rate_init:
# 0.0001
# 0.7828097500149924
# 1.3233105327270827
# 0.8616216498065623
#
#
# layer:
# (200, 200, 200, 200, 200)
# alpha:
# 0.001
# learning_rate_init:
# 0.001
# 0.7523810497075094
# 1.2765367552109175
# 0.8712310193308674
#
#
# layer:
# (200, 200, 200, 200, 200)
# alpha:
# 0.001
# learning_rate_init:
# 0.01
# 0.809476329097788
# 1.3523679541730185
# 0.8554778704658844
#
#
# layer:
# (400, 400, 400, 400, 400)
# alpha:
# 0.0001
# learning_rate_init:
# 0.0001
# 0.7354087049788441
# 1.2670462856692768
# 0.8731385794334675
#
#
# layer:
# (400, 400, 400, 400, 400)
# alpha:
# 0.0001
# learning_rate_init:
# 0.001
# 0.7210834717068321
# 1.2181809389620244
# 0.8827350535659082
#
#
# layer:
# (400, 400, 400, 400, 400)
# alpha:
# 0.0001
# learning_rate_init:
# 0.01
# 1.09822023158044
# 1.668916181139617
# 0.7799032342159666
#
#
# layer:
# (400, 400, 400, 400, 400)
# alpha:
# 0.001
# learning_rate_init:
# 0.0001
# 0.7480623985315938
# 1.259298518320854
# 0.8746853069272776
#
#
# layer:
# (400, 400, 400, 400, 400)
# alpha:
# 0.001
# learning_rate_init:
# 0.001
# 0.7374701680381274
# 1.2273189684847214
# 0.8809691588072195
#
#
# layer:
# (400, 400, 400, 400, 400)
# alpha:
# 0.001
# learning_rate_init:
# 0.01
# 1.144344489493909
# 1.7860265120577485
# 0.7479304345619695
#
#
# layer:
# (800, 800, 800, 800, 800)
# alpha:
# 0.0001
# learning_rate_init:
# 0.0001
# 0.7164769247946566
# 1.2425574536845487
# 0.8779950172737561
#
#
# layer:
# (800, 800, 800, 800, 800)
# alpha:
# 0.0001
# learning_rate_init:
# 0.001
# 0.7047243875704032
# 1.2220152229587966
# 0.8819956975232537
#
#
# layer:
# (800, 800, 800, 800, 800)
# alpha:
# 0.0001
# learning_rate_init:
# 0.01
# 1.3837501747816483
# 2.4104959533232444
# 0.5408470029244814
#
#
# layer:
# (800, 800, 800, 800, 800)
# alpha:
# 0.001
# learning_rate_init:
# 0.0001
# 0.7130998128517733
# 1.2365630636794585
# 0.8791693394034192
#
#
# layer:
# (800, 800, 800, 800, 800)
# alpha:
# 0.001
# learning_rate_init:
# 0.001
# 0.7403565540891522
# 1.2836211929083459
# 0.869797786476223
#
#
# layer:
# (800, 800, 800, 800, 800)
# alpha:
# 0.001
# learning_rate_init:
# 0.01
# 0.9999381149807788
# 1.651940076247805
# 0.78435808064854

# %% [markdown]
# # acidic

# %%
df_train = pd.read_csv('./Dataset/acidic_train_0.70_FP.csv',header = None)
df_val = pd.read_csv('./Dataset/acidic_val_0.15_FP.csv',header = None)

# %%
train_data_label = np.array(df_train)
print(train_data_label.shape)
val_data_label = np.array(df_val)
print(val_data_label.shape)
X_train, X_val, y_train, y_val = train_data_label[:,1:],val_data_label[:,1:],train_data_label[:,0],val_data_label[:,0]
# Out:
# (6337, 9122)
# (1358, 9122)

# %%
learning_rate_init_list = [0.0001,0.0003,0.001,0.003,0.01]

# %%
for learning_rate_init in learning_rate_init_list:
    model = MLPRegressor((200, 200, 200, 200),alpha = 0.0001,learning_rate_init = learning_rate_init,random_state= 0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    print('learning_rate_init:')
    print(learning_rate_init)
    print(mean_absolute_error(y_val, y_pred))
    print(mean_squared_error(y_val, y_pred)**0.5)
    print(r2_score(y_val, y_pred))
    print('\n')
# Out:
# learning_rate_init:
# 0.0001
# 0.7819733282225614
# 1.340945773085709
# 0.857908846043477
#
#
# learning_rate_init:
# 0.0003
# 0.7240650018922689
# 1.2349171686532459
# 0.8794907823378119
#
#
# learning_rate_init:
# 0.001
# 0.7016450961188139
# 1.2153664436152278
# 0.8832762874172333
#
#
# learning_rate_init:
# 0.003
# 0.7083791125493512
# 1.2416607694871842
# 0.8781710420777247
#
#
# learning_rate_init:
# 0.01
# 0.8121274507965855
# 1.366548831923369
# 0.8524310726255762
