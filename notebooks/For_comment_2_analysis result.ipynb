# %%
import pandas as pd

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
pka_graph = pd.read_csv('./Predict_result/For_comment_all_SAMPL6_result.csv')

# %%
pka_graph
# Out:
#                                                smiles Molecule ID     pKa ID  \
# 0                           O=C1NCCCc2c1oc1ccc(O)cc21        SM01  SM01_pKa1
# 1                   FC(F)(F)c1cccc(Nc2ncnc3ccccc23)c1        SM02  SM02_pKa1
# 2                     O=C(Nc1nnc(Cc2ccccc2)s1)c1cccs1        SM03  SM03_pKa1
# 3                        Clc1ccc(CNc2ncnc3ccccc23)cc1        SM04  SM04_pKa1
# 4                   O=C(Nc1ccccc1N1CCCCC1)c1ccc(Cl)o1        SM05  SM05_pKa1
# 5                    O=C(Nc1cccc2cccnc12)c1cncc(Br)c1        SM06  SM06_pKa1
# 6                    O=C(Nc1cccc2cccnc12)c1cncc(Br)c1        SM06  SM06_pKa2
# 7                          c1ccc(CNc2ncnc3ccccc23)cc1        SM07  SM07_pKa1
# 8          Cc1ccc2[nH]c(=O)c(CC(=O)O)c(-c3ccccc3)c2c1        SM08  SM08_pKa1
# 9                         COc1cccc(Nc2ncnc3ccccc23)c1        SM09  SM09_pKa1
# 10                 O=C(CNC(=O)c1ccccc1)Nc1nc2ccccc2s1        SM10  SM10_pKa1
# ...

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 1']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 1'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 1'])))
# Out:
# 0.7363686380778435
# 0.5938437165172414
# 0.9162229510054022

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 2']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 2'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 2'])))
# Out:
# 0.6801887843283432
# 0.5633873820344827
# 0.9285185383575669

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 3']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 3'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 3'])))
# Out:
# 0.761267511708796
# 0.6234038551724138
# 0.9104616507863779

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['Epik Scan']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['Epik Scan'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['Epik Scan'])))
# Out:
# 0.9619179834562571
# 0.7844827586206897
# 0.8570413035468399

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['Epik Microscopic']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['Epik Microscopic'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['Epik Microscopic'])))
# Out:
# 0.9724799439470772
# 0.7834482758620689
# 0.8538846650547984

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['ACD/pKa classic']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['ACD/pKa classic'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['ACD/pKa classic'])))
# Out:
# 0.7832712129929507
# 0.5499999999999999
# 0.9052108077864081

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['Chemicalize v18.23']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['Chemicalize v18.23'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['Chemicalize v18.23'])))
# Out:
# 1.2476847524031502
# 1.006896551724138
# 0.7594838592480754

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['MoKa']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['MoKa'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['MoKa'])))
# Out:
# 0.9704638066409278
# 0.7993103448275864
# 0.854489887219686

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['''Hunt's model''']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['''Hunt's model'''])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['''Hunt's model'''])))
# Out:
# 0.8636762843438106
# 0.6868620689655173
# 0.8847511819321637

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['''Yang's XGBoost''']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['''Yang's XGBoost'''])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['''Yang's XGBoost'''])))
# Out:
# 1.0108327055555184
# 0.7672413793103449
# 0.8421323800765801

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['''Yang's Neural Network''']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['''Yang's Neural Network'''])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['''Yang's Neural Network'''])))
# Out:
# 1.1407740868556662
# 0.8324137931034483
# 0.7989362463556969

# %%
pka_graph_ensembl = (pka_graph['graph pka 1'] + pka_graph['graph pka 2'] + pka_graph['graph pka 3'])/3
pka_graph_ensembl
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph_ensembl))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph_ensembl)))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph_ensembl)))
# Out:
# 0.6781031308778085
# 0.5369156041379312
# 0.928956231512949

# %%
pka_graph_7 = pd.read_csv('./Predict_result/For_comment_SAMPL7_result.csv')

# %%
pka_graph_7
# Out:
#                                           smiles   pKa (exp)  graph pka 1  \
# 0               O=C(CCc1ccccc1)NS(=O)(=O)c1ccccc1       4.49     4.693657
# 1                      CC(=O)NS(=O)(=O)CCc1ccccc1       4.91     4.951441
# 2                   CC1(NS(=O)(=O)CCc2ccccc2)COC1      10.45    12.197288
# 3                   CS(=O)(=O)NC1(CCc2ccccc2)COC1      10.05    12.228244
# 4            O=S(=O)(NC1(CCc2ccccc2)COC1)c1ccccc1      10.29    11.542145
# 5               CN(C)S(=O)(=O)NC1(CCc2ccccc2)COC1      11.02    12.505786
# 6                   CS(=O)(=O)NC1(CCc2ccccc2)CSC1      10.45    12.007244
# 7               CN(C)S(=O)(=O)NC1(CCc2ccccc2)CSC1      11.93    12.335575
# 8          CS(=O)(=O)NC1(CCc2ccccc2)C[S+]([O-])C1       9.87    11.110368
# 9   O=S(=O)(NC1(CCc2ccccc2)C[S+]([O-])C1)c1ccccc1       9.80    10.304191
# 10     CN(C)S(=O)(=O)NC1(CCc2ccccc2)C[S+]([O-])C1      10.33    11.222630
# 11          CS(=O)(=O)NC1(CCc2ccccc2)CS(=O)(=O)C1       9.44    10.159642
# ...

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 1']))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 1'])))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 1'])))
# Out:
# 1.075912669216372
# 0.9146612205500002
# 0.790199620198624

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 2']))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 2'])))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 2'])))
# Out:
# 0.7612511240404252
# 0.6165741622
# 0.8949712683515493

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 3']))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 3'])))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 3'])))
# Out:
# 0.9650134065535573
# 0.7424888786499999
# 0.831220801257202

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['Chemicalize']))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['Chemicalize'])))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['Chemicalize'])))
# Out:
# 0.707633379653617
# 0.5585000000000001
# 0.9092453578740928

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['Epik Scan']))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['Epik Scan'])))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['Epik Scan'])))
# Out:
# 1.6481140737218405
# 1.1210000000000004
# 0.5077034831825392

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['''Yang's XGBoost''']))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['''Yang's XGBoost'''])))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['''Yang's XGBoost'''])))
# Out:
# 1.621766012715768
# 1.4765000000000001
# 0.5233181497141222

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['''Yang's neural network''']))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['''Yang's neural network'''])))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['''Yang's neural network'''])))
# Out:
# 1.156116343626367
# 0.9315
# 0.7577547285770236

# %%
pka_graph_7['graph pka 1']
# Out:
# 0      4.693657
# 1      4.951441
# 2     12.197288
# 3     12.228244
# 4     11.542145
# 5     12.505786
# 6     12.007244
# 7     12.335575
# 8     11.110368
# 9     10.304191
# 10    11.222630
# 11    10.159642
# 12     9.264742
# 13     9.990362
# 14     5.937761
# 15     5.127365
# 16     6.235569
# 17     5.721827
# 18     4.819913
# 19     6.274833
# Name: graph pka 1, dtype: float64

# %%
pka_graph_7['graph pka 2']
# Out:
# 0      4.431005
# 1      4.878375
# 2     10.462682
# 3     10.519570
# 4      9.740994
# 5     11.187289
# 6     10.360854
# 7     11.043975
# 8     10.608087
# 9     10.177500
# 10    11.022433
# 11    10.539411
# 12     9.694185
# 13    11.131069
# 14     6.061480
# 15     5.377483
# 16     6.810569
# 17     5.648724
# 18     4.916687
# 19     6.523676
# Name: graph pka 2, dtype: float64

# %%
pka_graph_7['graph pka 3']
# Out:
# 0      4.755572
# 1      5.081221
# 2     10.792910
# 3     11.206064
# 4     10.085660
# 5     11.865122
# 6     11.234811
# 7     11.866784
# 8      8.288017
# 9      7.799403
# 10     8.490375
# 11     9.392019
# 12     8.794205
# 13     9.923714
# 14     5.869885
# 15     5.435533
# 16     6.609465
# 17     6.356681
# 18     5.914379
# 19     7.340707
# Name: graph pka 3, dtype: float64

# %%
pka_graph_ensembl = (pka_graph_7['graph pka 1'] + pka_graph_7['graph pka 2'] + pka_graph_7['graph pka 3'])/3
pka_graph_ensembl
# Out:
# 0      4.626745
# 1      4.970346
# 2     11.150960
# 3     11.317959
# 4     10.456266
# 5     11.852732
# 6     11.200970
# 7     11.748778
# 8     10.002157
# 9      9.427031
# 10    10.245146
# 11    10.030357
# 12     9.251044
# 13    10.348382
# 14     5.956376
# 15     5.313461
# 16     6.551868
# 17     5.909077
# 18     5.216993
# 19     6.713072
# dtype: float64

# %%
list(pka_graph_7['pKa (exp)'])
# Out:
# [4.49,
#  4.91,
#  10.45,
#  10.05,
#  10.29,
#  11.02,
#  10.45,
#  11.93,
#  9.87,
#  9.8,
#  10.33,
#  9.44,
#  10.22,
#  9.58,
#  5.22,
#  6.62,
#  5.62,
#  6.34,
#  5.93,
#  6.42]

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_ensembl))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_ensembl)))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_ensembl)))
# Out:
# 0.6847812484600724
# 0.5713329803000002
# 0.9150123254928872

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
OPERA_predict_6= [6.97,6.16,6.89,6.94,2.8,3.82,6.73,3.17,6.08,9.34,3.79,5.07,3.57,3.92,9.95,4.25,6.18,9.85,5.29,4.15,7.9,4.79]
label_6 = [9.53,5.03,7.02,6.02,4.59,3.03,6.08,4.22,5.37,9.02,3.89,5.28,5.77,5.3,8.94,5.37,9.58,9.56,5.7,4.1,7.43,5.45]

# %%
print(mean_squared_error(OPERA_predict_6,label_6)**0.5)
print(mean_absolute_error(OPERA_predict_6,label_6))
print(r2_score(OPERA_predict_6,label_6))
# print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 1'])))
# print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 1'])))
# Out:
# 1.2827119707868948
# 0.9704545454545453
# 0.6188243065203421

# %%
OPERA_predict_7 = [7.05,7.51,10.06,8.39,9.31,8.78,7.31,6.77,6.91,8.02,6.23,7,8.01,5.92,6.38,7.04,5.43,7.2]
label_7 = [4.49,4.91,10.45,10.05,10.29,11.02,10.45,11.93,9.87,9.8,10.33,9.44,10.22,9.58,5.22,6.62,5.62,6.42]

# %%
print(mean_squared_error(OPERA_predict_7,label_7)**0.5)
print(mean_absolute_error(OPERA_predict_7,label_7))
print(r2_score(OPERA_predict_7,label_7))
# Out:
# 2.5146713944812396
# 2.135
# -3.751826432549324
