# %%
import pandas as pd

# %%
data = pd.read_csv('./Predict_result/typeIII_submission_full_collection.csv')
data
# Out:
#      pKa error (calc - exp) Molecule ID             name  pKa (calc)  \
# 0                     -0.41        SM01        Epik Scan        9.12
# 1                     -0.98        SM02        Epik Scan        4.05
# 2                      0.10        SM03        Epik Scan        7.12
# 3                     -0.42        SM04        Epik Scan        5.60
# 4                      0.76        SM05        Epik Scan        5.35
# ..                      ...         ...              ...         ...
# 149                    0.14        SM21  ACD/pKa Classic        4.24
# 150                    0.03        SM22  ACD/pKa Classic        2.43
# 151                    0.16        SM22  ACD/pKa Classic        7.59
# 152                   -0.09        SM23  ACD/pKa Classic        5.36
# 153                    2.14        SM24  ACD/pKa Classic        4.74
#
#      pKa (exp)     pKa ID  pKa SEM (calc)  pKa SEM (exp)      participant  \
# 0         9.53  SM01_pKa1            1.12           0.01   Bas Rustenburg
# 1         5.03  SM02_pKa1            1.47           0.01   Bas Rustenburg
# 2         7.02  SM03_pKa1            2.22           0.01   Bas Rustenburg
# 3         6.02  SM04_pKa1            1.13           0.01   Bas Rustenburg
# 4         4.59  SM05_pKa1            2.22           0.01   Bas Rustenburg
# ..         ...        ...             ...            ...              ...
# 149       4.10  SM21_pKa1            0.10           0.01  Kiril Lanevskij
# 150       2.40  SM22_pKa1            0.30           0.02  Kiril Lanevskij
# 151       7.43  SM22_pKa2            0.10           0.01  Kiril Lanevskij
# 152       5.45  SM23_pKa1            0.10           0.01  Kiril Lanevskij
# 153       2.60  SM24_pKa1            0.40           0.01  Kiril Lanevskij
#
#     receipt_id
# 0        nb007
# 1        nb007
# 2        nb007
# 3        nb007
# 4        nb007
# ..         ...
# 149      xmyhm
# 150      xmyhm
# 151      xmyhm
# 152      xmyhm
# 153      xmyhm
#
# [154 rows x 10 columns]

# %%
Epik_Scan = data[(data['name'] == 'Epik Scan') & (data['pKa ID'] != 'SM18_pKa3')&(data['pKa ID'] != 'SM14_pKa1')]
Epik_Scan = Epik_Scan.sort_values(by=['Molecule ID','pKa (exp)'])
print(len(Epik_Scan))
Epik_Scan
# Out:
# 29
#     pKa error (calc - exp) Molecule ID       name  pKa (calc)  pKa (exp)  \
# 0                    -0.41        SM01  Epik Scan        9.12       9.53
# 1                    -0.98        SM02  Epik Scan        4.05       5.03
# 2                     0.10        SM03  Epik Scan        7.12       7.02
# 3                    -0.42        SM04  Epik Scan        5.60       6.02
# 4                     0.76        SM05  Epik Scan        5.35       4.59
# 5                    -0.85        SM06  Epik Scan        2.18       3.03
# 6                    -1.41        SM06  Epik Scan       10.33      11.74
# 7                    -0.48        SM07  Epik Scan        5.60       6.08
# 8                    -0.11        SM08  Epik Scan        4.11       4.22
# 9                    -1.32        SM09  Epik Scan        4.05       5.37
# 10                   -0.35        SM10  Epik Scan        8.67       9.02
# 11                   -0.02        SM11  Epik Scan        3.87       3.89
# 12                   -1.23        SM12  Epik Scan        4.05       5.28
# 13                   -1.50        SM13  Epik Scan        4.27       5.77
# 14                    1.05        SM14  Epik Scan        6.35       5.30
# 16                    1.12        SM15  Epik Scan        5.82       4.70
# 17                   -0.23        SM15  Epik Scan        8.71       8.94
# 18                   -0.66        SM16  Epik Scan        4.71       5.37
# 19                   -0.80        SM16  Epik Scan        9.85      10.65
# 20                    1.74        SM17  Epik Scan        4.90       3.16
# 21                    0.33        SM18  Epik Scan        2.48       2.15
# 22                   -0.20        SM18  Epik Scan        9.38       9.58
# 24                   -0.39        SM19  Epik Scan        9.17       9.56
# 25                    2.35        SM20  Epik Scan        8.05       5.70
# 26                   -0.21        SM21  Epik Scan        3.89       4.10
# 27                    1.16        SM22  Epik Scan        3.56       2.40
# 28                   -0.64        SM22  Epik Scan        6.79       7.43
# 29                    0.54        SM23  Epik Scan        5.99       5.45
# 30                    1.39        SM24  Epik Scan        3.99       2.60
#
#        pKa ID  pKa SEM (calc)  pKa SEM (exp)     participant receipt_id
# 0   SM01_pKa1            1.12           0.01  Bas Rustenburg      nb007
# 1   SM02_pKa1            1.47           0.01  Bas Rustenburg      nb007
# 2   SM03_pKa1            2.22           0.01  Bas Rustenburg      nb007
# 3   SM04_pKa1            1.13           0.01  Bas Rustenburg      nb007
# 4   SM05_pKa1            2.22           0.01  Bas Rustenburg      nb007
# 5   SM06_pKa1            1.12           0.04  Bas Rustenburg      nb007
# 6   SM06_pKa2            2.22           0.01  Bas Rustenburg      nb007
# 7   SM07_pKa1            1.13           0.01  Bas Rustenburg      nb007
# 8   SM08_pKa1            2.22           0.01  Bas Rustenburg      nb007
# 9   SM09_pKa1            1.47           0.01  Bas Rustenburg      nb007
# 10  SM10_pKa1            2.22           0.01  Bas Rustenburg      nb007
# 11  SM11_pKa1            2.00           0.01  Bas Rustenburg      nb007
# 12  SM12_pKa1            1.47           0.01  Bas Rustenburg      nb007
# 13  SM13_pKa1            2.22           0.01  Bas Rustenburg      nb007
# 14  SM14_pKa2            2.22           0.01  Bas Rustenburg      nb007
# 16  SM15_pKa1            1.12           0.01  Bas Rustenburg      nb007
# 17  SM15_pKa2            1.47           0.01  Bas Rustenburg      nb007
# 18  SM16_pKa1            0.94           0.01  Bas Rustenburg      nb007
# 19  SM16_pKa2            2.22           0.01  Bas Rustenburg      nb007
# 20  SM17_pKa1            0.75           0.01  Bas Rustenburg      nb007
# 21  SM18_pKa1            2.22           0.02  Bas Rustenburg      nb007
# 22  SM18_pKa2            2.22           0.03  Bas Rustenburg      nb007
# 24  SM19_pKa1            2.22           0.02  Bas Rustenburg      nb007
# 25  SM20_pKa1            2.22           0.03  Bas Rustenburg      nb007
# 26  SM21_pKa1            2.22           0.01  Bas Rustenburg      nb007
# 27  SM22_pKa1            1.40           0.02  Bas Rustenburg      nb007
# 28  SM22_pKa2            0.86           0.01  Bas Rustenburg      nb007
# 29  SM23_pKa1            0.75           0.01  Bas Rustenburg      nb007
# 30  SM24_pKa1            2.22           0.01  Bas Rustenburg      nb007

# %%
ACD = data[(data['name'] == 'ACD/pKa Classic') & (data['pKa ID'] != 'SM18_pKa3')&(data['pKa ID'] != 'SM14_pKa1')]
ACD = ACD.sort_values(by=['Molecule ID','pKa (exp)'])
print(len(ACD))
ACD
# Out:
# 29
#      pKa error (calc - exp) Molecule ID             name  pKa (calc)  \
# 124                   -0.53        SM01  ACD/pKa Classic        9.00
# 125                   -0.51        SM02  ACD/pKa Classic        4.52
# 126                    1.15        SM03  ACD/pKa Classic        8.17
# 127                   -0.89        SM04  ACD/pKa Classic        5.13
# 128                    1.18        SM05  ACD/pKa Classic        5.77
# 129                   -1.06        SM06  ACD/pKa Classic        1.97
# 130                   -0.90        SM06  ACD/pKa Classic       10.84
# 131                   -0.57        SM07  ACD/pKa Classic        5.51
# 132                   -0.29        SM08  ACD/pKa Classic        3.93
# 133                   -0.59        SM09  ACD/pKa Classic        4.78
# 134                    0.14        SM10  ACD/pKa Classic        9.16
# 135                    0.04        SM11  ACD/pKa Classic        3.93
# 136                   -0.84        SM12  ACD/pKa Classic        4.44
# 137                   -0.76        SM13  ACD/pKa Classic        5.01
# 139                   -0.14        SM14  ACD/pKa Classic        5.16
# 140                    0.08        SM15  ACD/pKa Classic        4.78
# 141                    0.13        SM15  ACD/pKa Classic        9.07
# 142                   -0.18        SM16  ACD/pKa Classic        5.19
# 143                    0.20        SM16  ACD/pKa Classic       10.85
# 144                   -2.17        SM17  ACD/pKa Classic        0.99
# 145                    0.19        SM18  ACD/pKa Classic        2.34
# 146                   -0.19        SM18  ACD/pKa Classic        9.39
# 147                    0.35        SM19  ACD/pKa Classic        9.91
# 148                    0.31        SM20  ACD/pKa Classic        6.01
# 149                    0.14        SM21  ACD/pKa Classic        4.24
# 150                    0.03        SM22  ACD/pKa Classic        2.43
# 151                    0.16        SM22  ACD/pKa Classic        7.59
# 152                   -0.09        SM23  ACD/pKa Classic        5.36
# 153                    2.14        SM24  ACD/pKa Classic        4.74
#
#      pKa (exp)     pKa ID  pKa SEM (calc)  pKa SEM (exp)      participant  \
# 124       9.53  SM01_pKa1            0.20           0.01  Kiril Lanevskij
# 125       5.03  SM02_pKa1            0.10           0.01  Kiril Lanevskij
# 126       7.02  SM03_pKa1            0.10           0.01  Kiril Lanevskij
# 127       6.02  SM04_pKa1            0.10           0.01  Kiril Lanevskij
# 128       4.59  SM05_pKa1            0.40           0.01  Kiril Lanevskij
# 129       3.03  SM06_pKa1            0.10           0.04  Kiril Lanevskij
# 130      11.74  SM06_pKa2            0.43           0.01  Kiril Lanevskij
# 131       6.08  SM07_pKa1            0.10           0.01  Kiril Lanevskij
# 132       4.22  SM08_pKa1            0.10           0.01  Kiril Lanevskij
# 133       5.37  SM09_pKa1            0.10           0.01  Kiril Lanevskij
# 134       9.02  SM10_pKa1            0.70           0.01  Kiril Lanevskij
# 135       3.89  SM11_pKa1            0.30           0.01  Kiril Lanevskij
# 136       5.28  SM12_pKa1            0.10           0.01  Kiril Lanevskij
# 137       5.77  SM13_pKa1            0.10           0.01  Kiril Lanevskij
# 139       5.30  SM14_pKa2            0.10           0.01  Kiril Lanevskij
# 140       4.70  SM15_pKa1            0.10           0.01  Kiril Lanevskij
# 141       8.94  SM15_pKa2            0.26           0.01  Kiril Lanevskij
# 142       5.37  SM16_pKa1            0.26           0.01  Kiril Lanevskij
# 143      10.65  SM16_pKa2            0.70           0.01  Kiril Lanevskij
# 144       3.16  SM17_pKa1            0.10           0.01  Kiril Lanevskij
# 145       2.15  SM18_pKa1            0.20           0.02  Kiril Lanevskij
# 146       9.58  SM18_pKa2            0.50           0.03  Kiril Lanevskij
# 147       9.56  SM19_pKa1            0.70           0.02  Kiril Lanevskij
# 148       5.70  SM20_pKa1            0.10           0.03  Kiril Lanevskij
# 149       4.10  SM21_pKa1            0.10           0.01  Kiril Lanevskij
# 150       2.40  SM22_pKa1            0.30           0.02  Kiril Lanevskij
# 151       7.43  SM22_pKa2            0.10           0.01  Kiril Lanevskij
# 152       5.45  SM23_pKa1            0.10           0.01  Kiril Lanevskij
# 153       2.60  SM24_pKa1            0.40           0.01  Kiril Lanevskij
#
#     receipt_id
# 124      xmyhm
# 125      xmyhm
# 126      xmyhm
# 127      xmyhm
# 128      xmyhm
# 129      xmyhm
# 130      xmyhm
# 131      xmyhm
# 132      xmyhm
# 133      xmyhm
# 134      xmyhm
# 135      xmyhm
# 136      xmyhm
# 137      xmyhm
# 139      xmyhm
# 140      xmyhm
# 141      xmyhm
# 142      xmyhm
# 143      xmyhm
# 144      xmyhm
# 145      xmyhm
# 146      xmyhm
# 147      xmyhm
# 148      xmyhm
# 149      xmyhm
# 150      xmyhm
# 151      xmyhm
# 152      xmyhm
# 153      xmyhm

# %%
MoKa = data[(data['name'] == 'MoKa') & (data['pKa ID'] != 'SM18_pKa3')&(data['pKa ID'] != 'SM14_pKa1')]
MoKa = MoKa.sort_values(by=['Molecule ID','pKa (exp)'])
print(len(MoKa))
MoKa
# Out:
# 29
#     pKa error (calc - exp) Molecule ID  name  pKa (calc)  pKa (exp)  \
# 31                    1.19        SM01  MoKa       10.72       9.53
# 32                   -0.14        SM02  MoKa        4.89       5.03
# 33                   -0.94        SM03  MoKa        6.08       7.02
# 34                   -0.91        SM04  MoKa        5.11       6.02
# 35                   -1.08        SM05  MoKa        3.51       4.59
# 37                    1.05        SM06  MoKa        4.08       3.03
# 36                   -1.17        SM06  MoKa       10.57      11.74
# 38                   -0.97        SM07  MoKa        5.11       6.08
# 39                   -1.47        SM08  MoKa        2.75       4.22
# 40                   -0.48        SM09  MoKa        4.89       5.37
# 41                    2.14        SM10  MoKa       11.16       9.02
# 42                    0.34        SM11  MoKa        4.23       3.89
# 43                   -0.39        SM12  MoKa        4.89       5.28
# 44                   -0.13        SM13  MoKa        5.64       5.77
# 45                    0.79        SM14  MoKa        6.09       5.30
# 48                    0.25        SM15  MoKa        4.95       4.70
# 47                    0.45        SM15  MoKa        9.39       8.94
# 50                    0.24        SM16  MoKa        5.61       5.37
# 49                    0.16        SM16  MoKa       10.81      10.65
# 51                    2.11        SM17  MoKa        5.27       3.16
# 54                    0.27        SM18  MoKa        2.42       2.15
# 52                   -0.98        SM18  MoKa        8.60       9.58
# 55                    0.41        SM19  MoKa        9.97       9.56
# 56                    1.06        SM20  MoKa        6.76       5.70
# 57                    1.31        SM21  MoKa        5.41       4.10
# 59                   -0.40        SM22  MoKa        2.00       2.40
# 58                    0.23        SM22  MoKa        7.66       7.43
# 60                    0.61        SM23  MoKa        6.06       5.45
# 61                    1.51        SM24  MoKa        4.11       2.60
#
#        pKa ID  pKa SEM (calc)  pKa SEM (exp) participant receipt_id
# 31  SM01_pKa1             NaN           0.01  Thomas Fox      nb017
# 32  SM02_pKa1             NaN           0.01  Thomas Fox      nb017
# 33  SM03_pKa1             NaN           0.01  Thomas Fox      nb017
# 34  SM04_pKa1             NaN           0.01  Thomas Fox      nb017
# 35  SM05_pKa1             NaN           0.01  Thomas Fox      nb017
# 37  SM06_pKa1             NaN           0.04  Thomas Fox      nb017
# 36  SM06_pKa2             NaN           0.01  Thomas Fox      nb017
# 38  SM07_pKa1             NaN           0.01  Thomas Fox      nb017
# 39  SM08_pKa1             NaN           0.01  Thomas Fox      nb017
# 40  SM09_pKa1             NaN           0.01  Thomas Fox      nb017
# 41  SM10_pKa1             NaN           0.01  Thomas Fox      nb017
# 42  SM11_pKa1             NaN           0.01  Thomas Fox      nb017
# 43  SM12_pKa1             NaN           0.01  Thomas Fox      nb017
# 44  SM13_pKa1             NaN           0.01  Thomas Fox      nb017
# 45  SM14_pKa2             NaN           0.01  Thomas Fox      nb017
# 48  SM15_pKa1             NaN           0.01  Thomas Fox      nb017
# 47  SM15_pKa2             NaN           0.01  Thomas Fox      nb017
# 50  SM16_pKa1             NaN           0.01  Thomas Fox      nb017
# 49  SM16_pKa2             NaN           0.01  Thomas Fox      nb017
# 51  SM17_pKa1             NaN           0.01  Thomas Fox      nb017
# 54  SM18_pKa1             NaN           0.02  Thomas Fox      nb017
# 52  SM18_pKa2             NaN           0.03  Thomas Fox      nb017
# 55  SM19_pKa1             NaN           0.02  Thomas Fox      nb017
# 56  SM20_pKa1             NaN           0.03  Thomas Fox      nb017
# 57  SM21_pKa1             NaN           0.01  Thomas Fox      nb017
# 59  SM22_pKa1             NaN           0.02  Thomas Fox      nb017
# 58  SM22_pKa2             NaN           0.01  Thomas Fox      nb017
# 60  SM23_pKa1             NaN           0.01  Thomas Fox      nb017
# 61  SM24_pKa1             NaN           0.01  Thomas Fox      nb017

# %%
Epik_Micro = data[(data['name'] == 'Epik Microscopic') & (data['pKa ID'] != 'SM18_pKa3')&(data['pKa ID'] != 'SM14_pKa1')]
Epik_Micro = Epik_Micro.sort_values(by=['Molecule ID','pKa (exp)'])
print(len(Epik_Micro))
Epik_Micro
# Out:
# 29
#     pKa error (calc - exp) Molecule ID              name  pKa (calc)  \
# 62                   -0.41        SM01  Epik Microscopic        9.12
# 63                   -0.87        SM02  Epik Microscopic        4.16
# 64                    0.10        SM03  Epik Microscopic        7.12
# 65                   -0.41        SM04  Epik Microscopic        5.61
# 66                    0.76        SM05  Epik Microscopic        5.35
# 67                   -0.86        SM06  Epik Microscopic        2.17
# 68                   -1.41        SM06  Epik Microscopic       10.33
# 69                   -0.47        SM07  Epik Microscopic        5.61
# 70                   -0.11        SM08  Epik Microscopic        4.11
# 71                   -1.21        SM09  Epik Microscopic        4.16
# 72                   -0.35        SM10  Epik Microscopic        8.67
# 73                   -0.02        SM11  Epik Microscopic        3.87
# 74                   -1.12        SM12  Epik Microscopic        4.16
# 75                   -1.33        SM13  Epik Microscopic        4.44
# 77                    1.05        SM14  Epik Microscopic        6.35
# 78                    1.12        SM15  Epik Microscopic        5.82
# 79                   -0.23        SM15  Epik Microscopic        8.71
# 80                   -0.66        SM16  Epik Microscopic        4.71
# 81                   -0.80        SM16  Epik Microscopic        9.85
# 82                    1.74        SM17  Epik Microscopic        4.90
# 83                    0.08        SM18  Epik Microscopic        2.23
# 84                   -0.42        SM18  Epik Microscopic        9.16
# 86                   -0.39        SM19  Epik Microscopic        9.17
# 87                    2.35        SM20  Epik Microscopic        8.05
# 88                   -0.20        SM21  Epik Microscopic        3.90
# 89                    1.10        SM22  Epik Microscopic        3.50
# 90                   -0.64        SM22  Epik Microscopic        6.79
# 91                    0.55        SM23  Epik Microscopic        6.00
# 92                   -1.96        SM24  Epik Microscopic        0.64
#
#     pKa (exp)     pKa ID  pKa SEM (calc)  pKa SEM (exp)     participant  \
# 62       9.53  SM01_pKa1            1.09           0.01  Bas Rustenburg
# 63       5.03  SM02_pKa1            1.01           0.01  Bas Rustenburg
# 64       7.02  SM03_pKa1            1.98           0.01  Bas Rustenburg
# 65       6.02  SM04_pKa1            1.12           0.01  Bas Rustenburg
# 66       4.59  SM05_pKa1            2.03           0.01  Bas Rustenburg
# 67       3.03  SM06_pKa1            2.14           0.04  Bas Rustenburg
# 68      11.74  SM06_pKa2            1.14           0.01  Bas Rustenburg
# 69       6.08  SM07_pKa1            1.12           0.01  Bas Rustenburg
# 70       4.22  SM08_pKa1            1.95           0.01  Bas Rustenburg
# 71       5.37  SM09_pKa1            1.01           0.01  Bas Rustenburg
# 72       9.02  SM10_pKa1            1.76           0.01  Bas Rustenburg
# 73       3.89  SM11_pKa1            1.70           0.01  Bas Rustenburg
# 74       5.28  SM12_pKa1            1.01           0.01  Bas Rustenburg
# 75       5.77  SM13_pKa1            1.60           0.01  Bas Rustenburg
# 77       5.30  SM14_pKa2            1.97           0.01  Bas Rustenburg
# 78       4.70  SM15_pKa1            1.03           0.01  Bas Rustenburg
# 79       8.94  SM15_pKa2            1.95           0.01  Bas Rustenburg
# 80       5.37  SM16_pKa1            1.86           0.01  Bas Rustenburg
# 81      10.65  SM16_pKa2            2.08           0.01  Bas Rustenburg
# 82       3.16  SM17_pKa1            0.75           0.01  Bas Rustenburg
# 83       2.15  SM18_pKa1            1.16           0.02  Bas Rustenburg
# 84       9.58  SM18_pKa2            1.07           0.03  Bas Rustenburg
# 86       9.56  SM19_pKa1            1.70           0.02  Bas Rustenburg
# 87       5.70  SM20_pKa1            2.26           0.03  Bas Rustenburg
# 88       4.10  SM21_pKa1            1.71           0.01  Bas Rustenburg
# 89       2.40  SM22_pKa1            0.84           0.02  Bas Rustenburg
# 90       7.43  SM22_pKa2            1.75           0.01  Bas Rustenburg
# 91       5.45  SM23_pKa1            0.90           0.01  Bas Rustenburg
# 92       2.60  SM24_pKa1            0.71           0.01  Bas Rustenburg
#
#    receipt_id
# 62      nb010
# 63      nb010
# 64      nb010
# 65      nb010
# 66      nb010
# 67      nb010
# 68      nb010
# 69      nb010
# 70      nb010
# 71      nb010
# 72      nb010
# 73      nb010
# 74      nb010
# 75      nb010
# 77      nb010
# 78      nb010
# 79      nb010
# 80      nb010
# 81      nb010
# 82      nb010
# 83      nb010
# 84      nb010
# 86      nb010
# 87      nb010
# 88      nb010
# 89      nb010
# 90      nb010
# 91      nb010
# 92      nb010

# %%
Chemicalize = data[(data['name'] == 'Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)') & (data['pKa ID'] != 'SM18_pKa3')&(data['pKa ID'] != 'SM14_pKa1')]
Chemicalize= Chemicalize.sort_values(by=['Molecule ID','pKa (exp)'])
print(len(Chemicalize))
Chemicalize
# Out:
# 29
#      pKa error (calc - exp) Molecule ID  \
# 93                    -0.09        SM01
# 94                    -1.02        SM02
# 95                     0.66        SM03
# 96                    -1.19        SM04
# 97                    -0.40        SM05
# 98                     0.39        SM06
# 99                     2.11        SM06
# 100                   -1.25        SM07
# 101                   -0.02        SM08
# 102                   -1.37        SM09
# 103                   -1.25        SM10
# 104                   -0.47        SM11
# 105                   -1.27        SM12
# 106                   -1.09        SM13
# 108                    1.10        SM14
# 109                    0.21        SM15
# 110                    1.70        SM15
# 111                    0.24        SM16
# 112                    3.33        SM16
# 113                   -0.68        SM17
# 114                   -0.60        SM18
# 115                   -1.54        SM18
# 117                   -1.67        SM19
# 118                    1.50        SM20
# 119                   -2.15        SM21
# 120                    0.94        SM22
# 121                   -0.04        SM22
# 122                   -0.43        SM23
# 123                    0.49        SM24
#
#                                                   name  pKa (calc)  pKa (exp)  \
# 93   Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        9.44       9.53
# 94   Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        4.01       5.03
# 95   Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        7.68       7.02
# 96   Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        4.83       6.02
# 97   Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        4.19       4.59
# 98   Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        3.42       3.03
# 99   Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)       13.85      11.74
# 100  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        4.83       6.08
# 101  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        4.20       4.22
# 102  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        4.00       5.37
# 103  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        7.77       9.02
# 104  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        3.42       3.89
# 105  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        4.01       5.28
# 106  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        4.68       5.77
# 108  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        6.40       5.30
# 109  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        4.91       4.70
# 110  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)       10.64       8.94
# 111  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        5.61       5.37
# 112  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)       13.98      10.65
# 113  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        2.48       3.16
# 114  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        1.55       2.15
# 115  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        8.04       9.58
# 117  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        7.89       9.56
# 118  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        7.20       5.70
# 119  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        1.95       4.10
# 120  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        3.34       2.40
# 121  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        7.39       7.43
# 122  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        5.02       5.45
# 123  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)        3.09       2.60
#
#         pKa ID  pKa SEM (calc)  pKa SEM (exp)  participant receipt_id
# 93   SM01_pKa1             NaN           0.01  Mehtap Isik      nb015
# 94   SM02_pKa1             NaN           0.01  Mehtap Isik      nb015
# 95   SM03_pKa1             NaN           0.01  Mehtap Isik      nb015
# 96   SM04_pKa1             NaN           0.01  Mehtap Isik      nb015
# 97   SM05_pKa1             NaN           0.01  Mehtap Isik      nb015
# 98   SM06_pKa1             NaN           0.04  Mehtap Isik      nb015
# 99   SM06_pKa2             NaN           0.01  Mehtap Isik      nb015
# 100  SM07_pKa1             NaN           0.01  Mehtap Isik      nb015
# 101  SM08_pKa1             NaN           0.01  Mehtap Isik      nb015
# 102  SM09_pKa1             NaN           0.01  Mehtap Isik      nb015
# 103  SM10_pKa1             NaN           0.01  Mehtap Isik      nb015
# 104  SM11_pKa1             NaN           0.01  Mehtap Isik      nb015
# 105  SM12_pKa1             NaN           0.01  Mehtap Isik      nb015
# 106  SM13_pKa1             NaN           0.01  Mehtap Isik      nb015
# 108  SM14_pKa2             NaN           0.01  Mehtap Isik      nb015
# 109  SM15_pKa1             NaN           0.01  Mehtap Isik      nb015
# 110  SM15_pKa2             NaN           0.01  Mehtap Isik      nb015
# 111  SM16_pKa1             NaN           0.01  Mehtap Isik      nb015
# 112  SM16_pKa2             NaN           0.01  Mehtap Isik      nb015
# 113  SM17_pKa1             NaN           0.01  Mehtap Isik      nb015
# 114  SM18_pKa1             NaN           0.02  Mehtap Isik      nb015
# 115  SM18_pKa2             NaN           0.03  Mehtap Isik      nb015
# 117  SM19_pKa1             NaN           0.02  Mehtap Isik      nb015
# 118  SM20_pKa1             NaN           0.03  Mehtap Isik      nb015
# 119  SM21_pKa1             NaN           0.01  Mehtap Isik      nb015
# 120  SM22_pKa1             NaN           0.02  Mehtap Isik      nb015
# 121  SM22_pKa2             NaN           0.01  Mehtap Isik      nb015
# 122  SM23_pKa1             NaN           0.01  Mehtap Isik      nb015
# 123  SM24_pKa1             NaN           0.01  Mehtap Isik      nb015

# %%
pka_graph = pd.read_csv('./Predict_result/SAMPL6_result.csv')
pka_graph= pka_graph.sort_values(by=['Molecule ID','pKa (exp)'])
print(len(pka_graph))
order = ['smiles', 'Molecule ID', 'pKa ID', 'pKa (exp)', 'graph pka 1', 'graph pka 2', 'graph pka 3']
pka_graph = pka_graph[order]
pka_graph
# Out:
# 29
#                                                smiles Molecule ID     pKa ID  \
# 0                           O=C1NCCCc2c1oc1ccc(O)cc21        SM01  SM01_pKa1
# 11                  FC(F)(F)c1cccc(Nc2ncnc3ccccc23)c1        SM02  SM02_pKa1
# 1                     O=C(Nc1nnc(Cc2ccccc2)s1)c1cccs1        SM03  SM03_pKa1
# 12                       Clc1ccc(CNc2ncnc3ccccc23)cc1        SM04  SM04_pKa1
# 13                  O=C(Nc1ccccc1N1CCCCC1)c1ccc(Cl)o1        SM05  SM05_pKa1
# 14                   O=C(Nc1cccc2cccnc12)c1cncc(Br)c1        SM06  SM06_pKa1
# 2                    O=C(Nc1cccc2cccnc12)c1cncc(Br)c1        SM06  SM06_pKa2
# 15                         c1ccc(CNc2ncnc3ccccc23)cc1        SM07  SM07_pKa1
# 3          Cc1ccc2[nH]c(=O)c(CC(=O)O)c(-c3ccccc3)c2c1        SM08  SM08_pKa1
# 16                        COc1cccc(Nc2ncnc3ccccc23)c1        SM09  SM09_pKa1
# 4                  O=C(CNC(=O)c1ccccc1)Nc1nc2ccccc2s1        SM10  SM10_pKa1
# 17                            Nc1ncnc2c1cnn2-c1ccccc1        SM11  SM11_pKa1
# 18                        Clc1cccc(Nc2ncnc3ccccc23)c1        SM12  SM12_pKa1
# 19                   COc1cc2ncnc(Nc3cccc(C)c3)c2cc1OC        SM13  SM13_pKa1
# 20                          Nc1ccc2c(c1)ncn2-c1ccccc1        SM14  SM14_pKa2
# 21                          Oc1ccc(-n2cnc3ccccc32)cc1        SM15  SM15_pKa1
# 5                           Oc1ccc(-n2cnc3ccccc32)cc1        SM15  SM15_pKa2
# 22                       O=C(Nc1ccncc1)c1c(Cl)cccc1Cl        SM16  SM16_pKa1
# 6                        O=C(Nc1ccncc1)c1c(Cl)cccc1Cl        SM16  SM16_pKa2
# 23                     c1ccc(CSc2nnc(-c3ccncc3)o2)cc1        SM17  SM17_pKa1
# 24  O=C(CCc1nc2ccccc2c(=O)[nH]1)Nc1ncc(Cc2ccc(F)c(...        SM18  SM18_pKa1
# 7   O=C(CCc1nc2ccccc2c(=O)[nH]1)Nc1ncc(Cc2ccc(F)c(...        SM18  SM18_pKa2
# 8           CCOc1ccc2nc(NC(=O)Cc3ccc(Cl)c(Cl)c3)sc2c1        SM19  SM19_pKa1
# 9       O=C1NC(=O)/C(=C\c2cccc(OCc3ccc(Cl)cc3Cl)c2)S1        SM20  SM20_pKa1
# 25              Fc1cnc(Nc2cccc(Br)c2)nc1Nc1cccc(Br)c1        SM21  SM21_pKa1
# 26                              Oc1c(I)cc(I)c2cccnc12        SM22  SM22_pKa1
# 10                              Oc1c(I)cc(I)c2cccnc12        SM22  SM22_pKa2
# 27  CCOC(=O)c1ccc(Nc2cc(C)nc(Nc3ccc(C(=O)OCC)cc3)n...        SM23  SM23_pKa1
# 28      COc1ccc(-c2oc3ncnc(NCCO)c3c2-c2ccc(OC)cc2)cc1        SM24  SM24_pKa1
#
#     pKa (exp)  graph pka 1  graph pka 2  graph pka 3
# 0        9.53     8.670529     8.631477     8.379063
# 11       5.03     3.834098     4.233867     4.259360
# 1        7.02     7.825701     7.473364     7.537795
# 12       6.02     4.930722     5.548564     5.221679
# 13       4.59     4.591392     4.558191     4.679179
# 14       3.03     3.862032     3.100895     3.761634
# 2       11.74    11.976712    11.269383    11.740337
# 15       6.08     4.930920     5.558676     5.221679
# 3        4.22     3.805479     4.013884     4.198157
# 16       5.37     3.974639     4.429934     4.260782
# 4        9.02     9.641075    10.418246     9.795728
# 17       3.89     3.830474     3.878787     3.628914
# 18       5.28     3.879416     4.275062     4.256599
# 19       5.77     5.066304     4.779203     5.032618
# 20       5.30     5.347182     4.816226     5.603992
# 21       4.70     4.897919     4.172761     4.757471
# 5        8.94     9.602269     8.812258     9.419638
# 22       5.37     5.256861     5.350735     5.471334
# 6       10.65    12.049109    11.944775    12.454751
# 23       3.16     3.463161     3.291993     3.570610
# 24       2.15     2.771059     2.835245     3.116422
# 7        9.58     9.807236     9.283881     9.472614
# 8        9.56     9.935365    10.134148     9.965655
# 9        5.70     5.174829     4.618419     6.481783
# 25       4.10     3.598081     3.245317     3.323534
# 26       2.40     2.503527     2.646540     2.647910
# 10       7.43     7.877353     8.090374     8.317771
# 27       5.45     5.473255     5.100140     5.917730
# 28       2.60     3.509475     3.339419     4.033972

# %%
pka_graph['Epik Scan'] = list(Epik_Scan['pKa (calc)'])
pka_graph['Epik Microscopic'] = list(Epik_Micro['pKa (calc)'])
pka_graph['ACD/pKa classic'] = list(ACD['pKa (calc)'])
pka_graph['MoKa'] = list(MoKa['pKa (calc)'])
pka_graph['Chemicalize v18.23'] = list(Chemicalize['pKa (calc)'])

# %%
pka_graph
# Out:
#                                                smiles Molecule ID     pKa ID  \
# 0                           O=C1NCCCc2c1oc1ccc(O)cc21        SM01  SM01_pKa1
# 11                  FC(F)(F)c1cccc(Nc2ncnc3ccccc23)c1        SM02  SM02_pKa1
# 1                     O=C(Nc1nnc(Cc2ccccc2)s1)c1cccs1        SM03  SM03_pKa1
# 12                       Clc1ccc(CNc2ncnc3ccccc23)cc1        SM04  SM04_pKa1
# 13                  O=C(Nc1ccccc1N1CCCCC1)c1ccc(Cl)o1        SM05  SM05_pKa1
# 14                   O=C(Nc1cccc2cccnc12)c1cncc(Br)c1        SM06  SM06_pKa1
# 2                    O=C(Nc1cccc2cccnc12)c1cncc(Br)c1        SM06  SM06_pKa2
# 15                         c1ccc(CNc2ncnc3ccccc23)cc1        SM07  SM07_pKa1
# 3          Cc1ccc2[nH]c(=O)c(CC(=O)O)c(-c3ccccc3)c2c1        SM08  SM08_pKa1
# 16                        COc1cccc(Nc2ncnc3ccccc23)c1        SM09  SM09_pKa1
# 4                  O=C(CNC(=O)c1ccccc1)Nc1nc2ccccc2s1        SM10  SM10_pKa1
# 17                            Nc1ncnc2c1cnn2-c1ccccc1        SM11  SM11_pKa1
# 18                        Clc1cccc(Nc2ncnc3ccccc23)c1        SM12  SM12_pKa1
# 19                   COc1cc2ncnc(Nc3cccc(C)c3)c2cc1OC        SM13  SM13_pKa1
# 20                          Nc1ccc2c(c1)ncn2-c1ccccc1        SM14  SM14_pKa2
# 21                          Oc1ccc(-n2cnc3ccccc32)cc1        SM15  SM15_pKa1
# 5                           Oc1ccc(-n2cnc3ccccc32)cc1        SM15  SM15_pKa2
# 22                       O=C(Nc1ccncc1)c1c(Cl)cccc1Cl        SM16  SM16_pKa1
# 6                        O=C(Nc1ccncc1)c1c(Cl)cccc1Cl        SM16  SM16_pKa2
# 23                     c1ccc(CSc2nnc(-c3ccncc3)o2)cc1        SM17  SM17_pKa1
# 24  O=C(CCc1nc2ccccc2c(=O)[nH]1)Nc1ncc(Cc2ccc(F)c(...        SM18  SM18_pKa1
# 7   O=C(CCc1nc2ccccc2c(=O)[nH]1)Nc1ncc(Cc2ccc(F)c(...        SM18  SM18_pKa2
# 8           CCOc1ccc2nc(NC(=O)Cc3ccc(Cl)c(Cl)c3)sc2c1        SM19  SM19_pKa1
# 9       O=C1NC(=O)/C(=C\c2cccc(OCc3ccc(Cl)cc3Cl)c2)S1        SM20  SM20_pKa1
# 25              Fc1cnc(Nc2cccc(Br)c2)nc1Nc1cccc(Br)c1        SM21  SM21_pKa1
# 26                              Oc1c(I)cc(I)c2cccnc12        SM22  SM22_pKa1
# 10                              Oc1c(I)cc(I)c2cccnc12        SM22  SM22_pKa2
# 27  CCOC(=O)c1ccc(Nc2cc(C)nc(Nc3ccc(C(=O)OCC)cc3)n...        SM23  SM23_pKa1
# 28      COc1ccc(-c2oc3ncnc(NCCO)c3c2-c2ccc(OC)cc2)cc1        SM24  SM24_pKa1
#
#     pKa (exp)  graph pka 1  graph pka 2  graph pka 3  Epik Scan  \
# 0        9.53     8.670529     8.631477     8.379063       9.12
# 11       5.03     3.834098     4.233867     4.259360       4.05
# 1        7.02     7.825701     7.473364     7.537795       7.12
# 12       6.02     4.930722     5.548564     5.221679       5.60
# 13       4.59     4.591392     4.558191     4.679179       5.35
# 14       3.03     3.862032     3.100895     3.761634       2.18
# 2       11.74    11.976712    11.269383    11.740337      10.33
# 15       6.08     4.930920     5.558676     5.221679       5.60
# 3        4.22     3.805479     4.013884     4.198157       4.11
# 16       5.37     3.974639     4.429934     4.260782       4.05
# 4        9.02     9.641075    10.418246     9.795728       8.67
# 17       3.89     3.830474     3.878787     3.628914       3.87
# 18       5.28     3.879416     4.275062     4.256599       4.05
# 19       5.77     5.066304     4.779203     5.032618       4.27
# 20       5.30     5.347182     4.816226     5.603992       6.35
# 21       4.70     4.897919     4.172761     4.757471       5.82
# 5        8.94     9.602269     8.812258     9.419638       8.71
# 22       5.37     5.256861     5.350735     5.471334       4.71
# 6       10.65    12.049109    11.944775    12.454751       9.85
# 23       3.16     3.463161     3.291993     3.570610       4.90
# 24       2.15     2.771059     2.835245     3.116422       2.48
# 7        9.58     9.807236     9.283881     9.472614       9.38
# 8        9.56     9.935365    10.134148     9.965655       9.17
# 9        5.70     5.174829     4.618419     6.481783       8.05
# 25       4.10     3.598081     3.245317     3.323534       3.89
# 26       2.40     2.503527     2.646540     2.647910       3.56
# 10       7.43     7.877353     8.090374     8.317771       6.79
# 27       5.45     5.473255     5.100140     5.917730       5.99
# 28       2.60     3.509475     3.339419     4.033972       3.99
#
#     Epik Microscopic  ACD/pKa classic   MoKa  Chemicalize v18.23
# 0               9.12             9.00  10.72                9.44
# 11              4.16             4.52   4.89                4.01
# 1               7.12             8.17   6.08                7.68
# 12              5.61             5.13   5.11                4.83
# 13              5.35             5.77   3.51                4.19
# 14              2.17             1.97   4.08                3.42
# 2              10.33            10.84  10.57               13.85
# 15              5.61             5.51   5.11                4.83
# 3               4.11             3.93   2.75                4.20
# 16              4.16             4.78   4.89                4.00
# 4               8.67             9.16  11.16                7.77
# 17              3.87             3.93   4.23                3.42
# 18              4.16             4.44   4.89                4.01
# 19              4.44             5.01   5.64                4.68
# 20              6.35             5.16   6.09                6.40
# 21              5.82             4.78   4.95                4.91
# 5               8.71             9.07   9.39               10.64
# 22              4.71             5.19   5.61                5.61
# 6               9.85            10.85  10.81               13.98
# 23              4.90             0.99   5.27                2.48
# 24              2.23             2.34   2.42                1.55
# 7               9.16             9.39   8.60                8.04
# 8               9.17             9.91   9.97                7.89
# 9               8.05             6.01   6.76                7.20
# 25              3.90             4.24   5.41                1.95
# 26              3.50             2.43   2.00                3.34
# 10              6.79             7.59   7.66                7.39
# 27              6.00             5.36   6.06                5.02
# 28              0.64             4.74   4.11                3.09

# %%
pka_graph.to_csv('./Predict_result/all_SAMPL6_result.csv',index = False)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 1']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 1'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 1'])))
# Out:
# 0.7363686380778435
# 0.5938437165172414
# 0.9162229510054022

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 2']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 2'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 2'])))
# Out:
# 0.6801887843283432
# 0.5633873820344827
# 0.9285185383575669

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 3']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 3'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['graph pka 3'])))
# Out:
# 0.761267511708796
# 0.6234038551724138
# 0.9104616507863779

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['Epik Scan']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['Epik Scan'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['Epik Scan'])))
# Out:
# 0.9619179834562571
# 0.7844827586206897
# 0.8570413035468399

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['Epik Microscopic']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['Epik Microscopic'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['Epik Microscopic'])))
# Out:
# 0.9724799439470772
# 0.7834482758620689
# 0.8538846650547984

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['ACD/pKa classic']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['ACD/pKa classic'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['ACD/pKa classic'])))
# Out:
# 0.7832712129929507
# 0.5499999999999999
# 0.9052108077864081

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['Chemicalize v18.23']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['Chemicalize v18.23'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['Chemicalize v18.23'])))
# Out:
# 1.2476847524031502
# 1.006896551724138
# 0.7594838592480754

# %%
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph['MoKa']))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph['MoKa'])))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph['MoKa'])))
# Out:
# 0.9704638066409278
# 0.7993103448275864
# 0.854489887219686

# %%
pka_graph_ensembl = (pka_graph['graph pka 1'] + pka_graph['graph pka 2'] + pka_graph['graph pka 3'])/3
pka_graph_ensembl
print(mean_squared_error(list(pka_graph['pKa (exp)']),list(pka_graph_ensembl))**0.5)
print(mean_absolute_error(list(pka_graph['pKa (exp)']),list(pka_graph_ensembl)))
print(r2_score(list(pka_graph['pKa (exp)']),list(pka_graph_ensembl)))
# Out:
# 0.6781031308778085
# 0.5369156041379312
# 0.928956231512949

# %%
pka_graph_7 = pd.read_csv('./Predict_result/SAMPL7_result.csv')

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 1']))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 1'])))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 1'])))
# Out:
# 1.075912669216372
# 0.9146612205500002
# 0.790199620198624

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 2']))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 2'])))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 2'])))
# Out:
# 0.7612511240404252
# 0.6165741622
# 0.8949712683515493

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 3']))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 3'])))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['graph pka 3'])))
# Out:
# 0.9650134065535573
# 0.7424888786499999
# 0.831220801257202

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['Chemicalize']))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['Chemicalize'])))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['Chemicalize'])))
# Out:
# 0.707633379653617
# 0.5585000000000001
# 0.9092453578740928

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['Epik Scan']))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['Epik Scan'])))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_7['Epik Scan'])))
# Out:
# 1.6481140737218405
# 1.1210000000000004
# 0.5077034831825392

# %%
pka_graph_7['graph pka 1']
# Out:
# 0      4.693657
# 1      4.951441
# 2     12.197288
# 3     12.228244
# 4     11.542145
# 5     12.505786
# 6     12.007244
# 7     12.335575
# 8     11.110368
# 9     10.304191
# 10    11.222630
# 11    10.159642
# 12     9.264742
# 13     9.990362
# 14     5.937761
# 15     5.127365
# 16     6.235569
# 17     5.721827
# 18     4.819913
# 19     6.274833
# Name: graph pka 1, dtype: float64

# %%
pka_graph_7['graph pka 2']
# Out:
# 0      4.431005
# 1      4.878375
# 2     10.462682
# 3     10.519570
# 4      9.740994
# 5     11.187289
# 6     10.360854
# 7     11.043975
# 8     10.608087
# 9     10.177500
# 10    11.022433
# 11    10.539411
# 12     9.694185
# 13    11.131069
# 14     6.061480
# 15     5.377483
# 16     6.810569
# 17     5.648724
# 18     4.916687
# 19     6.523676
# Name: graph pka 2, dtype: float64

# %%
pka_graph_7['graph pka 3']
# Out:
# 0      4.755572
# 1      5.081221
# 2     10.792910
# 3     11.206064
# 4     10.085660
# 5     11.865122
# 6     11.234811
# 7     11.866784
# 8      8.288017
# 9      7.799403
# 10     8.490375
# 11     9.392019
# 12     8.794205
# 13     9.923714
# 14     5.869885
# 15     5.435533
# 16     6.609465
# 17     6.356681
# 18     5.914379
# 19     7.340707
# Name: graph pka 3, dtype: float64

# %%
pka_graph_ensembl = (pka_graph_7['graph pka 1'] + pka_graph_7['graph pka 2'] + pka_graph_7['graph pka 3'])/3
pka_graph_ensembl
# Out:
# 0      4.626745
# 1      4.970346
# 2     11.150960
# 3     11.317959
# 4     10.456266
# 5     11.852732
# 6     11.200970
# 7     11.748778
# 8     10.002157
# 9      9.427031
# 10    10.245146
# 11    10.030357
# 12     9.251044
# 13    10.348382
# 14     5.956376
# 15     5.313461
# 16     6.551868
# 17     5.909077
# 18     5.216993
# 19     6.713072
# dtype: float64

# %%
list(pka_graph_7['pKa (exp)'])
# Out:
# [4.49,
#  4.91,
#  10.45,
#  10.05,
#  10.29,
#  11.02,
#  10.45,
#  11.93,
#  9.87,
#  9.8,
#  10.33,
#  9.44,
#  10.22,
#  9.58,
#  5.22,
#  6.62,
#  5.62,
#  6.34,
#  5.93,
#  6.42]

# %%
print(mean_squared_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_ensembl))**0.5)
print(mean_absolute_error(list(pka_graph_7['pKa (exp)']),list(pka_graph_ensembl)))
print(r2_score(list(pka_graph_7['pKa (exp)']),list(pka_graph_ensembl)))
# Out:
# 0.6847812484600724
# 0.5713329803000002
# 0.9150123254928872
